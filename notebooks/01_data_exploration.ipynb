# %%
import sys
from pathlib import Path

sys.path.append(str(Path("../src").resolve()))

from inspect_data import inspect_data
df_information = inspect_data('../data/raw/VIS_R34_26.his')
# Out:
# 文件名称:VIS_R34_26.his
# 文件大小为:847.20 KB

# %%
import pandas as pd

file_path = r'C:\projects\data-science-labs\04_rvr_analysis_project\data\raw\VIS_R34_26.his'

# 使用 \t (制表符) 作为分隔符
df = pd.read_csv(file_path, sep='\t')

# 查看前 5 行数据
display(df.head())

# 查看列名，确认是否已经干净地分开了
print(df.columns.tolist())
# Out:
#             CREATEDATE SITE RVR1M RVR_1A RVR1X RVR_10M RVR_10A RVR_10X  \
# 0  2026-06-26 00:00:00  R34
# 1  2026-06-26 00:00:15  R34
# 2  2026-06-26 00:00:30  R34
# 3  2026-06-26 00:00:45  R34
# 4  2026-06-26 00:01:00  R34
#
#   RVR_TEND MOR_1A  ...   VIS1K VIS1A VIS10A BL1A RVR DATA MOR_RAW VIS_RAW  \
# 0                  ...    4384               367    13166   13166   13166
# 1                  ...    4384               367    13166   13166   13166
# 2                  ...    4384               367    13166   13166   13166
# 3                  ...                       447            17599   17599
# 4                  ...    4505               499    17648   17648   17648
#
#   LIGHTS STATUS                         RVR DATA.1
# 0    100
# 1    100
# 2    100
# 3    100         VIS 17599 AL 0 BL 00447 AL 0F15C
# 4    100         VIS 17648 AL 0 BL 00499 AL 07B61
#
# [5 rows x 23 columns]
# ['CREATEDATE', 'SITE', 'RVR1M', 'RVR_1A', 'RVR1X', 'RVR_10M', 'RVR_10A', 'RVR_10X', 'RVR_TEND', 'MOR_1A', 'MOR_10M', 'MOR_10A', 'MOR_10X', 'VIS1K', 'VIS1A', 'VIS10A', 'BL1A', 'RVR DATA', 'MOR_RAW', 'VIS_RAW', 'LIGHTS', 'STATUS', 'RVR DATA.1']

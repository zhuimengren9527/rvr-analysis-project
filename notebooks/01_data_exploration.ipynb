# %%
# 建立系统访问src的路径
import sys
from pathlib import Path

sys.path.append(str(Path("../src").resolve()))

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# 导入数据审视函数

from inspect_data import inspect_data
df_information = inspect_data('../data/raw/VIS_R34_26.his')
# Out:
# 文件名称:VIS_R34_26.his
# 文件大小为:847.20 KB
# 文件类型:.his
# 文件修改时间:2026-06-28 13:32:03
#
# 预览数据前10行:
#
# 第1行:'History file\n'
# 第2行:'CREATEDATE\tSITE\tRVR1M\tRVR_1A\tRVR1X\tRVR_10M\tRVR_10A\tRVR_10X\tRVR_TEND\tMOR_1A\tMOR_10M\tMOR_10A\tMOR_10X\tVIS1K\tVIS1A\tVIS10A\tBL1A\tRVR DATA\tMOR_RAW\tVIS_RAW\tLIGHTS\tSTATUS\tRVR DATA\n'
# 第3行:'2026-06-26 00:00:00\tR34\t \t \t \t \t \t \t \t \t \t \t \t  4384\t \t \t367\t13166\t13166\t 13166\t  100\t \t \n'
# 第4行:'2026-06-26 00:00:15\tR34\t \t \t \t \t \t \t \t \t \t \t \t  4384\t \t \t367\t13166\t13166\t 13166\t  100\t \t \n'
# 第5行:'2026-06-26 00:00:30\tR34\t \t \t \t \t \t \t \t \t \t \t \t  4384\t \t \t367\t13166\t13166\t 13166\t  100\t \t \n'
# 第6行:'2026-06-26 00:00:45\tR34\t \t \t \t \t \t \t \t \t \t \t \t \t \t \t447\t \t17599\t 17599\t  100\t \tVIS 17599 AL 0 BL 00447 AL 0\x03F15C\n'
# 第7行:'2026-06-26 00:01:00\tR34\t \t \t \t \t \t \t \t \t \t \t \t  4505\t \t \t499\t17648\t17648\t 17648\t  100\t \tVIS 17648 AL 0 BL 00499 AL 0\x037B61\n'
# 第8行:'2026-06-26 00:01:15\tR34\t \t \t \t \t \t \t \t10000\t \t \t \t  4392\t10000\t \t504\t18281\t18281\t 18281\t  100\t \tVIS 18281 AL 0 BL 00504 AL 0\x03691E\n'
# 第9行:'2026-06-26 00:01:30\tR34\t \t \t \t \t \t \t \t10000\t \t \t \t  4392\t10000\t \t504\t18281\t18281\t 18281\t  100\t \tVIS 18281 AL 0 BL 00504 AL 0\x03691E\n'
# 第10行:'2026-06-26 00:01:45\tR34\t \t \t \t \t \t \t \t10000\t \t \t \t  4392\t10000\t \t504\t18281\t18281\t 18281\t  100\t \tVIS 18281 AL 0 BL 00504 AL 0\x03691E\n'
# 文件编码推测:{'encoding': 'Windows-1252', 'confidence': 0.7290937353030681, 'language': ''}
# 检测到Tab \t
# 列名所在行：
# 第2行
# 该文件的列名为: ['CREATEDATE', 'SITE', 'RVR1M', 'RVR_1A', 'RVR1X', 'RVR_10M', 'RVR_10A', 'RVR_10X', 'RVR_TEND', 'MOR_1A', 'MOR_10M', 'MOR_10A', 'MOR_10X', 'VIS1K', 'VIS1A', 'VIS10A', 'BL1A', 'RVR DATA', 'MOR_RAW', 'VIS_RAW', 'LIGHTS', 'STATUS', 'RVR DATA']

# %%
# 导入数据(调用数据加载函数)
from load_data import load_data
df = load_data('../data/raw/VIS_R34_26.his')
print(df.head())
# Out:
# 文件编码推测:{'encoding': 'Windows-1252', 'confidence': 0.7290937353030681, 'language': ''}
#
# 预览数据前10行:
#
# 第1行:'History file\n'
# 第2行:'CREATEDATE\tSITE\tRVR1M\tRVR_1A\tRVR1X\tRVR_10M\tRVR_10A\tRVR_10X\tRVR_TEND\tMOR_1A\tMOR_10M\tMOR_10A\tMOR_10X\tVIS1K\tVIS1A\tVIS10A\tBL1A\tRVR DATA\tMOR_RAW\tVIS_RAW\tLIGHTS\tSTATUS\tRVR DATA\n'
# 第3行:'2026-06-26 00:00:00\tR34\t \t \t \t \t \t \t \t \t \t \t \t  4384\t \t \t367\t13166\t13166\t 13166\t  100\t \t \n'
# 第4行:'2026-06-26 00:00:15\tR34\t \t \t \t \t \t \t \t \t \t \t \t  4384\t \t \t367\t13166\t13166\t 13166\t  100\t \t \n'
# 第5行:'2026-06-26 00:00:30\tR34\t \t \t \t \t \t \t \t \t \t \t \t  4384\t \t \t367\t13166\t13166\t 13166\t  100\t \t \n'
# 第6行:'2026-06-26 00:00:45\tR34\t \t \t \t \t \t \t \t \t \t \t \t \t \t \t447\t \t17599\t 17599\t  100\t \tVIS 17599 AL 0 BL 00447 AL 0\x03F15C\n'
# 第7行:'2026-06-26 00:01:00\tR34\t \t \t \t \t \t \t \t \t \t \t \t  4505\t \t \t499\t17648\t17648\t 17648\t  100\t \tVIS 17648 AL 0 BL 00499 AL 0\x037B61\n'
# 第8行:'2026-06-26 00:01:15\tR34\t \t \t \t \t \t \t \t10000\t \t \t \t  4392\t10000\t \t504\t18281\t18281\t 18281\t  100\t \tVIS 18281 AL 0 BL 00504 AL 0\x03691E\n'
# 第9行:'2026-06-26 00:01:30\tR34\t \t \t \t \t \t \t \t10000\t \t \t \t  4392\t10000\t \t504\t18281\t18281\t 18281\t  100\t \tVIS 18281 AL 0 BL 00504 AL 0\x03691E\n'
# 第10行:'2026-06-26 00:01:45\tR34\t \t \t \t \t \t \t \t10000\t \t \t \t  4392\t10000\t \t504\t18281\t18281\t 18281\t  100\t \tVIS 18281 AL 0 BL 00504 AL 0\x03691E\n'
# 检测到Tab \t
# 列名所在行：
# 第2行
# 数据读取成功: 5760行，23列
#             CREATEDATE SITE RVR1M RVR_1A RVR1X RVR_10M RVR_10A RVR_10X  \
# 0  2026-06-26 00:00:00  R34
# 1  2026-06-26 00:00:15  R34
# 2  2026-06-26 00:00:30  R34
# 3  2026-06-26 00:00:45  R34
# 4  2026-06-26 00:01:00  R34
#
#   RVR_TEND MOR_1A  ...   VIS1K VIS1A VIS10A BL1A RVR DATA MOR_RAW VIS_RAW  \
# 0                  ...    4384               367    13166   13166   13166
# 1                  ...    4384               367    13166   13166   13166
# 2                  ...    4384               367    13166   13166   13166
# 3                  ...                       447            17599   17599
# 4                  ...    4505               499    17648   17648   17648
#
#   LIGHTS STATUS                         RVR DATA.1
# 0    100
# 1    100
# 2    100
# 3    100         VIS 17599 AL 0 BL 00447 AL 0F15C
# 4    100         VIS 17648 AL 0 BL 00499 AL 07B61
#
# [5 rows x 23 columns]

# %%
# 建立系统访问src的路径
import sys
from pathlib import Path

sys.path.append(str(Path("../src").resolve()))

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# 导入数据审视函数

from inspect_data import inspect_data
df_information = inspect_data('../data/raw/VIS_R34_26.his')
# Out:
# 文件名称:VIS_R34_26.his
# 文件大小为:847.20 KB
# 文件类型:.his
# 文件修改时间:2026-06-28 13:32:03
#
# 预览数据前10行:
#
# 'History file\n'
# 'CREATEDATE\tSITE\tRVR1M\tRVR_1A\tRVR1X\tRVR_10M\tRVR_10A\tRVR_10X\tRVR_TEND\tMOR_1A\tMOR_10M\tMOR_10A\tMOR_10X\tVIS1K\tVIS1A\tVIS10A\tBL1A\tRVR DATA\tMOR_RAW\tVIS_RAW\tLIGHTS\tSTATUS\tRVR DATA\n'
# '2026-06-26 00:00:00\tR34\t \t \t \t \t \t \t \t \t \t \t \t  4384\t \t \t367\t13166\t13166\t 13166\t  100\t \t \n'
# '2026-06-26 00:00:15\tR34\t \t \t \t \t \t \t \t \t \t \t \t  4384\t \t \t367\t13166\t13166\t 13166\t  100\t \t \n'
# '2026-06-26 00:00:30\tR34\t \t \t \t \t \t \t \t \t \t \t \t  4384\t \t \t367\t13166\t13166\t 13166\t  100\t \t \n'
# '2026-06-26 00:00:45\tR34\t \t \t \t \t \t \t \t \t \t \t \t \t \t \t447\t \t17599\t 17599\t  100\t \tVIS 17599 AL 0 BL 00447 AL 0\x03F15C\n'
# '2026-06-26 00:01:00\tR34\t \t \t \t \t \t \t \t \t \t \t \t  4505\t \t \t499\t17648\t17648\t 17648\t  100\t \tVIS 17648 AL 0 BL 00499 AL 0\x037B61\n'
# ...
